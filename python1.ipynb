# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import math
# Importamos as bibliotecas necessárias, para confecção do codigo.

# %%
dados = np.loadtxt('dados/brazil-TAVG-Trend.txt', comments = '%')
#Baixamos os dados para o Jupyter e usamos a opção comments =  % para excluir os comentários anteriores, posto que os comentarios 
#estavam descritos com %,e importarmos somente os dados que necessitamos para as contas e plotagem.

# %%
print(dados)
# Out:
# [[  1.83200000e+03   1.00000000e+00  -5.75000000e-01 ...,              nan
#                nan              nan]
#  [  1.83200000e+03   2.00000000e+00  -1.00500000e+00 ...,              nan
#                nan              nan]
#  [  1.83200000e+03   3.00000000e+00  -7.93000000e-01 ...,              nan
#                nan              nan]
#  ...,
#  [  2.01300000e+03   7.00000000e+00   7.72000000e-01 ...,              nan
#                nan              nan]
#  [  2.01300000e+03   8.00000000e+00   1.86000000e-01 ...,              nan
#                nan              nan]
#  [  2.01300000e+03   9.00000000e+00              nan ...,              nan
#                nan              nan]]

# %%
type(dados)
# Out:
# numpy.ndarray

# %%
anual = dados[0:,4]
# Para selecionarmos a anomalia anual utilizamos [0:,4], para somente importarmos os dados necessarios para as operações.

# %%
print(anual)
# Out:
# [ nan  nan  nan ...,  nan  nan  nan]

# %%
media_anual = np.nanmean(anual)
# Com os recursos do numpy, foi possivel gerar uma media com dados "nan".

# %%
print(media_anual)
# Out:
# -0.229509107894

# %%
desvio_anual = np.nanstd(anual)
# Com os recursos do numpy, foi possivel gerar um desvio padrão com dados "nan".

# %%
print(desvio_anual)
# Out:
# 0.496111048439

# %%
dados_anos= dados[:,0]+1/12*(dados[:,1]-1)
print(dados1)
# Como na primeira existiam 12 valores repitidos, referentes a um ano, sendo diferenciados pela segunda coluna, usamos a formula 
# acima para torna cada valor diferente entre sí, se diferenciando no grafico, tomando cuidado para que o decimo segundo mês
#permanecesse no ano certo.
# Out:
# [ 1832.          1832.08333333  1832.16666667 ...,  2013.5         2013.58333333
#   2013.66666667]

# %%
plt.plot(dados_anos,anual,'r-')
plt.xlabel('Anos')
plt.ylabel('Média de temperatura anual(°C) ')
plt.title('Temperatura x Anos - Brasil')
# Definimos o grafico da função e demos o titulo e as variaveis do grafico.

# %%
plt.plot(dados_anos,anual,'r-')
plt.xlabel('Anos')
plt.ylabel('Média de temperatura anual(°C) ')
plt.title('Temperatura x Anos - Brasil')
plt.plot(dados_anos, dados[:,8],'k-')
plt.plot
# Para o bônus, definimos o grafico da função e demos o titulo e as variaveis do grafico.
# Out:
# <function matplotlib.pyplot.plot>
